# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# LR = 0.0005 and batch size = 8 (200x200)

train_loss = [1.4258, 1.1424, 0.9971, 0.9286, 0.8982, 0.8848, 0.8785, 0.8752, 0.8735, 0.8724, 0.8718, 0.8715, 0.8713, 0.8711, 0.8710]
train_mae = [0.2990, 0.2624, 0.2294, 0.2066, 0.1923, 0.1841, 0.1802, 0.1778, 0.1772, 0.1761, 0.1756, 0.1761, 0.1749, 0.1753, 0.1751]
val_loss = [1.2841, 1.1089, 1.0297, 0.9992, 0.9895, 0.9871, 0.9871, 0.9877, 0.9889, 0.9899, 0.9905, 0.9914, 0.9918, 0.9924, 0.9928]
val_mae = [0.2844, 0.2505, 0.2248, 0.2080, 0.1982, 0.1932, 0.1905, 0.1891, 0.1880, 0.1874, 0.1873, 0.1869, 0.1868, 0.1867, 0.1866]
test_mae = [ 0.6366666666666667, 1.1075, 1.1741666666666666, 1.1841666666666666, 1.19, 1.1525, 1.1983333333333333, 1.1475, 1.2158333333333333, 1.1908333333333334, 1.2241666666666666, 1.1708333333333334, 1.1591666666666667, 1.1958333333333333, 1.1858333333333333]
x = [i for i in range(1, 16, 1)]
plt.title("Loss Plot")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(x, train_loss) # Blue
plt.plot(x, val_loss) # Orange
plt.legend(["train_loss", "val_loss"], loc ="upper right")
plt.savefig("Loss.svg", format="svg")

plt.title("MAE Plot")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.plot(x, train_mae) # Blue
plt.plot(x, val_mae) # Orange
plt.plot(x, test_mae) # Green
plt.legend(["train_mae", "val_mae", "test_mae"], loc ="upper right")
plt.savefig("MAE.svg", format="svg")

# %%
# LR = 0.005 and batch size = 16

train_loss = [1.0355, 0.8741, 0.8716, 0.8712, 0.8713]
train_mae = [0.2095, 0.1773, 0.1748, 0.1751, 0.1748]
val_loss = [2911.5610, 0.9903, 0.9920, 0.9955, 0.9944]
val_mae = [0.1260, 0.1874, 0.1877, 0.1857, 0.1865]
test_mae = [0.5341666666666667, 0.535, 0.5341666666666667, 0.5341666666666667, 0.5341666666666667]
x = [i for i in range(1, 6, 1)]
plt.title("Loss Plot")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(x, train_loss) # Blue
plt.plot(x, val_loss) # Orange
plt.legend(["train_loss", "val_loss"], loc ="upper right")
plt.savefig("Loss.svg", format="svg")

plt.title("MAE Plot")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.plot(x, train_mae) # Blue
plt.plot(x, val_mae) # Orange
plt.plot(x, test_mae) # Green
plt.legend(["train_mae", "val_mae", "test_mae"], loc ="upper right")
plt.savefig("MAE.svg", format="svg")

# %%
# LR = 0.005 and batch size = 32

train_loss = [0.8716, 0.8713, 0.8712, 0.8713, 0.8712]
train_mae = [0.1745, 0.1750, 0.1747, 0.1758, 0.1739]
val_loss = [0.9935, 0.9939, 0.9946, 0.9966, 0.9944]
val_mae = [0.1869, 0.1883, 0.1875, 0.1848, 0.1871]
test_mae = [0.5341666666666667, 0.5341666666666667, 0.5341666666666667, 0.5341666666666667, 0.5341666666666667]
x = [i for i in range(1, 6, 1)]
plt.title("Loss Plot")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(x, train_loss) # Blue
plt.plot(x, val_loss) # Orange
plt.legend(["train_loss", "val_loss"], loc ="upper right")
plt.savefig("Loss.svg", format="svg")

plt.title("MAE Plot")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.plot(x, train_mae) # Blue
plt.plot(x, val_mae) # Orange
plt.plot(x, test_mae) # Green
plt.legend(["train_mae", "val_mae", "test_mae"], loc ="upper right")
plt.savefig("MAE.svg", format="svg")



accuracy = 0.7416666666666667
precision = 0.7416666666666667
recall = 0.7416666666666667
F1_Score = 0.7416666666666667
Confusion_Matrix = [[890, 0, 0, 0, 0], [70, 0, 0, 0, 0], [177, 0, 0, 0, 0], [35, 0, 0, 0, 0], [28, 0, 0, 0, 0]]
kappa = 0

# class_weight is giving terrible results - 4% validation accuracy






Accuracy:  0.74
Recall:  0.74
Precision:  0.74
F1_Score:  0.74
# Confusion Matrix:  [[888   0   1   1   0]
#  [ 70   0   0   0   0]
#  [176   1   0   0   0]
#  [ 35   0   0   0   0]
#  [ 28   0   0   0   0]]
# after second epoch

# %%
train_loss = [1.3912, 1.1017, 0.8856, 0.7031, 0.5368, 0.3656, 0.2581, 0.2018, 0.1683, 0.1574]
train_accuracy = [0.3646, 0.4993, 0.6058, 0.7057, 0.7798, 0.8618, 0.9037, 0.9271, 0.9435, 0.9452]
val_loss = [1.5651, 1.2433, 1.3459, 1.2450, 1.5928, 1.6052, 1.3341, 2.8912, 2.0593, 1.7847]
val_accuracy = [0.1900, 0.5250, 0.3083, 0.5100, 0.3150, 0.3983, 0.3083, 0.2517, 0.2717, 0.2867]
x = [i for i in range(1, 11, 1)]

plt.title("Loss Plot")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(x, train_loss) # Blue
plt.plot(x, val_loss) # Orange
plt.legend(["train_loss", "val_loss"], loc ="upper right")
plt.savefig("Loss.svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (1).svg", format="svg")

# %%
train_loss = [1.5279, 1.2561, 1.1061, 0.9707, 0.8471, 0.7326, 0.6227, 0.5568, 0.4565, 0.4176]
train_accuracy = [0.3151, 0.4550, 0.5279, 0.5870, 0.6609, 0.7219, 0.7710, 0.7900, 0.8456, 0.8572]
val_loss = [1.3990, 1.6359, 1.3736, 1.4247, 1.4156, 1.9515, 1.7506, 1.3511, 1.4054, 1.7123]
val_accuracy = [0.5667, 0.2150, 0.3500, 0.3417, 0.3667, 0.2533, 0.3133, 0.4483, 0.4450, 0.3617]
x = [i for i in range(1, 11, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss.svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (2).svg", format="svg")

# %%
train_loss = [1.5060, 1.2478, 1.1146, 0.9758, 0.8623, 0.7448, 0.6410, 0.5455, 0.4666, 0.4000]
train_accuracy = [0.3248, 0.4621, 0.5160, 0.6037, 0.6573, 0.7128, 0.7595, 0.8072, 0.8408, 0.8680]
val_loss = [1.9291, 1.2457, 1.2622, 1.5951, 1.4103, 1.4636, 1.5004, 1.5968, 1.7724, 1.6289]
val_accuracy = [0.1067, 0.4767, 0.4050, 0.2567, 0.3650, 0.3867, 0.3633, 0.3300, 0.2967, 0.3617]
x = [i for i in range(1, 11, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss.svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (3).svg", format="svg")

# %%
test_loss = [1.5281, 1.2693, 1.1198, 1.0011, 0.8874, 0.7721, 0.6599, 0.5866, 0.5134, 0.4476]
test_accuracy = [0.3232, 0.4430, 0.5229, 0.5822, 0.6349, 0.6961, 0.7455, 0.7884, 0.8160, 0.8527]
val_loss = [1.5010, 1.2834, 1.1535, 1.2922, 1.5226, 1.5218, 1.1269, 1.6456, 1.5477, 1.8377]
val_accuracy = [0.1933, 0.4267, 0.5150, 0.4167, 0.2550, 0.3683, 0.5833, 0.3233, 0.3633, 0.3300]
x = [i for i in range(1, 11, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss.svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (4).svg", format="svg")

# %%
train_loss = [1.7519, 1.6273, 1.5656, 1.5088, 1.4772, 1.4430, 1.4119, 1.3915, 1.3494, 1.3402, 1.3022, 1.2790, 1.2515, 1.2361, 1.2210, 1.2054, 1.1711, 1.1613, 1.1340, 1.1227]
train_accuracy = [0.2238, 0.2686, 0.3048, 0.3272, 0.3441, 0.3653, 0.3696, 0.3897, 0.4111, 0.4175, 0.4361, 0.4385, 0.4669, 0.4647, 0.4862, 0.4788, 0.5107, 0.5219, 0.5286, 0.5298]
val_loss = [1.9022, 1.6901, 1.4834, 1.5065, 1.4504, 1.4206, 1.3798, 1.3694, 1.3666, 1.3777, 1.3626, 1.3533, 1.2933, 1.2976, 1.3792, 1.3593, 1.2991, 1.4162, 1.3263, 1.4613]
val_accuracy = [0.1783, 0.1817, 0.3050, 0.2817, 0.3650, 0.3700, 0.4050, 0.3783, 0.3700, 0.3550, 0.3583, 0.3650, 0.4383, 0.4400, 0.3450, 0.3533, 0.4217, 0.3200, 0.4300, 0.2967]
x = [i for i in range(1, 21, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss.svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (4).svg", format="svg")

# %%
train_loss = [1.5533, 1.3148, 1.1372, 1.0155, 0.9042, 0.7994, 0.7039, 0.6367, 0.5677, 0.5005]
train_accuracy = [0.2939, 0.4130, 0.5195, 0.5684, 0.6432, 0.6928, 0.7312, 0.7741, 0.7996, 0.8365]
val_loss = [1.4801, 1.4933, 1.3302, 1.1837, 1.1624, 1.2226, 1.1622, 1.3930, 1.1262, 1.2449]
val_accuracy = [0.1767, 0.1950, 0.3650, 0.5333, 0.5583, 0.4417, 0.5167, 0.3567, 0.5767, 0.4300]
x = [i for i in range(1, 11, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss (8).svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (6).svg", format="svg")

# %%
y = [0.2825, 0.3625, 0.5125, 0.4033333333333333, 0.30666666666666664, 0.3725, 0.49083333333333334, 0.35583333333333333, 0.33916666666666667, 0.345]
x = [i for i in range(1, 11, 1)]

plt.title("Test Result")
plt.xlabel("Epoch")
plt.ylabel("Precision/Accuracy/Recall/F1_Score")
plt.plot(x, y) # Blue
plt.savefig("Test.svg", format="svg")

# %%
train_loss = [1.2679, 0.7751, 0.5758, 0.4545, 0.3762]
train_accuracy = [0.4883, 0.7050, 0.7817, 0.8337, 0.8652]
val_loss = [1.288, 1.0839, 1.140, 2.2838, 2.8498]
val_accuracy = [0.5083, 0.6467, 0.6650, 0.1767, 0.1800]
x = [i for i in range(1, 6, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss (9).svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (6).svg", format="svg")

# %%
train_loss = [1.4683, 1.195, 0.8598, 0.6939, 0.5826]
train_accuracy = [0.3778, 0.5728, 0.6797, 0.7437, 0.7830]
val_loss = [1.6062, 1.6939, 1.9208, 2.0669, 2.4402]
val_accuracy = [0.2117, 0.2050, 0.1733, 0.1633, 0.1617]
x = [i for i in range(1, 6, 1)]

# plt.title("Loss Plot")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x, train_loss) # Blue
# plt.plot(x, val_loss) # Orange
# plt.legend(["train_loss", "val_loss"], loc ="upper right")
# plt.savefig("Loss (10).svg", format="svg")

plt.title("Accuracy Plot")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_accuracy) # Blue
plt.plot(x, val_accuracy) # Orange
plt.legend(["train_accuracy", "val_accuracy"], loc ="upper right")
plt.savefig("Accuracy (8).svg", format="svg")
